# %%
import pandas as pd

# %%
df_2024 = pd.read_csv(r"C:\Users\abhis\OneDrive\Desktop\ProjectH\Western India Hourly 2024-2025\IN_WE_2024_Electricity_Data.csv")
df_2025 = pd.read_csv(r"C:\Users\abhis\OneDrive\Desktop\ProjectH\Western India Hourly 2024-2025\IN_WE_2025_Electricity_Data.csv")

# %%
df_combined = pd.concat([df_2024, df_2025], axis=0, ignore_index=True)

# %%
print(df_combined.shape)
print(df_combined.head(5))
# Out:
# (17544, 22)
#                Datetime (UTC) Country      Zone name Zone id  \
# 0  2024-01-01T00:00:00.000000   India  Western India   IN-WE
# 1  2024-01-01T01:00:00.000000   India  Western India   IN-WE
# 2  2024-01-01T02:00:00.000000   India  Western India   IN-WE
# 3  2024-01-01T03:00:00.000000   India  Western India   IN-WE
# 4  2024-01-01T04:00:00.000000   India  Western India   IN-WE
#
#    Carbon intensity gCO2eq/kWh (direct)  \
# 0                                671.32
# 1                                661.71
# 2                                641.31
# 3                                610.32
# 4                                605.03
#
#    Carbon intensity gCO2eq/kWh (Life cycle)  \
# 0                                    727.46
# 1                                    717.21
# 2                                    696.59
# 3                                    665.20
# 4                                    659.91
#
# ...

# %%
df_combined.to_csv("electricity_IN_WE_2024_2025_combined.csv", index=False)

# %%
from IPython.display import FileLink
FileLink("electricity_2024_2025_combined.csv")
# Out:
# C:\Users\abhis\electricity_2024_2025_combined.csv
