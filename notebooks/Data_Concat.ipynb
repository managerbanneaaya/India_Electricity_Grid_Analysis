# %%
import pandas as pd

# %%
df_2024 = pd.read_csv(r"C:\Users\abhis\OneDrive\Desktop\ProjectH\MAINLAND_INDIA\Main Files\IN_2024_Electricity_Data.csv")
df_2025 = pd.read_csv(r"C:\Users\abhis\OneDrive\Desktop\ProjectH\MAINLAND_INDIA\Main Files\IN_2025_Electricity_Data.csv")

# %%
df_combined = pd.concat([df_2024, df_2025], axis=0, ignore_index=True)

# %%
print(df_combined.shape)
print(df_combined.head(5))
# Out:
# (17544, 22)
#                Datetime (UTC) Country       Zone name Zone id  \
# 0  2024-01-01T00:00:00.000000   India  Mainland India      IN
# 1  2024-01-01T01:00:00.000000   India  Mainland India      IN
# 2  2024-01-01T02:00:00.000000   India  Mainland India      IN
# 3  2024-01-01T03:00:00.000000   India  Mainland India      IN
# 4  2024-01-01T04:00:00.000000   India  Mainland India      IN
#
#    Carbon intensity gCO₂eq/kWh (direct)  \
# 0                                642.29
# 1                                636.72
# 2                                604.22
# 3                                564.08
# 4                                556.63
#
#    Carbon intensity gCO₂eq/kWh (Life cycle)  \
# 0                                    697.70
# 1                                    691.88
# 2                                    658.99
# 3                                    618.42
# 4                                    610.90
#
# ...

# %%
df_combined.to_csv("electricity_2024_2025_combined.csv", index=False)

# %%
from IPython.display import FileLink
FileLink("electricity_2024_2025_combined.csv")
# Out:
# C:\Users\abhis\electricity_2024_2025_combined.csv
